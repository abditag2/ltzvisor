# %%
import time
# %matplotlib notebook


from collections import deque

import numpy as np
import matplotlib.pyplot as plt
import time

filePath = '/home/fardin/devel/ltzvisor/pc/cmake-build-debug/state.csv'

# %%
def pltsin(ax, x, y, colors=['b']):
    ax.cla()
    for color in colors:
        ax.plot(x, y, color)

    fig.canvas.draw()

# %%
fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(-1,1)


lastLine = '--'
time_vector = np.linspace(0,1,100)
elevation = deque([0] * 100)

while True:
    f = open(filePath,'r')
    lines = f.readlines()
    if lines[-1] != lastLine:
        lastLine = lines[-1]
        line = lastLine.split(',')
        
        elevation_sample = float(line[0])
        elevation.popleft()
        elevation.append(elevation_sample)
        
        pltsin(ax, time_vector, elevation, ['r'])        
        print(lines[-1])
        

    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -0.231099,-0.006165,0.000000,0.251153,-0.017173,0.000000
#
# 0.035539,-0.000439,0.000000,0.193641,0.019915,0.000000
#
# 0.083195,0.005075,0.000000,-0.073568,-0.008909,0.000000
#
# -0.017976,-0.001704,0.000000,-0.083996,-0.000873,0.000000
#
# -0.046785,-0.001267,0.000000,0.021740,-0.000256,0.000000
#
# -0.009166,-0.000582,0.000000,0.035424,0.001904,0.000000
#
# 0.005846,0.000603,0.000000,-0.005238,-0.000305,0.000000
#
# -0.007545,-0.000317,0.000000,-0.014571,-0.000688,0.000000
#
# -0.014895,-0.000594,0.000000,0.000455,0.000011,0.000000
#
# -0.010285,-0.000366,0.000000,0.005882,0.000245,0.000000
#
# -0.006932,-0.000211,0.000000,0.000302,0.000054,0.000000
#
# -0.008478,-0.000292,0.000000,-0.002325,-0.000295,0.000000
#
# -0.009960,-0.000400,0.000000,-0.000349,0.000245,0.000000
#
# -0.009475,-0.000277,0.000000,0.000949,-0.000169,0.000000
#
# -0.008780,-0.000375,0.000000,0.000217,0.000121,0.000000
#
# -0.008957,-0.000276,0.000000,-0.000415,-0.000113,0.000000
