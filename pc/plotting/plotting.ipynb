# %%
import time
# %matplotlib notebook

import os
from collections import deque

import numpy as np
import matplotlib.pyplot as plt
import time

filePath = '/home/fardin/devel/ltzvisor/pc/cmake-build-debug/state.csv'

# %%
def pltsin(ax, x, y, colors=['b']):
    ax.cla()
    for color in colors:
        ax.plot(x, y, color)

    fig.canvas.draw()

# %%
fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(-1,1)


lastLine = '--'
time_vector = np.linspace(0,1,100)
elevation = deque([0] * 100)

while True:
    f = open(filePath,'r')
    lines = f.readlines()
    if lines[-1] != lastLine:
        lastLine = lines[-1]
        line = lastLine.split(',')
        
        elevation_sample = float(line[0])
        elevation.popleft()
        elevation.append(elevation_sample)
        
        pltsin(ax, time_vector, elevation, ['r'])        
        print(lines[-1])
        

    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -0.230945,-0.006209,0.000000,0.253314,-0.017719,0.000000
#
# -0.084470,-0.009338,0.000000,0.297776,0.007230,0.000000
#
# 0.043160,-0.000592,0.000000,0.191042,0.021541,0.000000
#
# 0.099470,0.007175,0.000000,0.032020,0.005801,0.000000
#
# 0.084362,0.005338,0.000000,-0.081980,-0.010521,0.000000
#
# 0.031295,-0.000018,0.000000,-0.115445,-0.008159,0.000000
#
# -0.021180,-0.001974,0.000000,-0.084437,-0.000073,0.000000
#
# -0.048773,-0.001370,0.000000,-0.024307,0.001394,0.000000
#
# -0.047684,-0.001222,0.000000,0.024543,-0.000433,0.000000
#
# -0.029028,-0.001330,0.000000,0.043704,0.000497,0.000000
#
# -0.008007,-0.000633,0.000000,0.035828,0.002141,0.000000
#
# 0.004759,0.000354,0.000000,0.013984,0.001345,0.000000
#
# 0.006355,0.000609,0.000000,-0.006268,-0.000317,0.000000
