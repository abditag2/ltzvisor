# %%
import time
# %matplotlib notebook

import os
from collections import deque

import numpy as np
import matplotlib.pyplot as plt
import time

filePath = '/home/fardin/devel/ltzvisor/pc/cmake-build-debug/state.csv'

# %%
def pltsin(ax, x, y, colors=['b']):
    ax.cla()
    for color in colors:
        ax.plot(x, y, color)

    fig.canvas.draw()

# %%
fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(-1,1)


lastLine = '--'
time_vector = np.linspace(0,1,100)
elevation = deque([0] * 100)

while True:
    f = open(filePath,'r')
    lines = f.readlines()
    if lines[-1] != lastLine:
        lastLine = lines[-1]
        line = lastLine.split(',')
        
        elevation_sample = float(line[0])
        elevation.popleft()
        elevation.append(elevation_sample)
        
        pltsin(ax, time_vector, elevation, ['r'])        
        print(lines[-1])
        

    time.sleep(0.1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -0.230945,-0.006209,0.000000,0.253314,-0.017719,0.000000
#
# -0.084470,-0.009338,0.000000,0.297776,0.007230,0.000000
#
# 0.043160,-0.000592,0.000000,0.191042,0.021541,0.000000
#
# 0.099470,0.007175,0.000000,0.032020,0.005801,0.000000
#
# 0.084362,0.005338,0.000000,-0.081980,-0.010521,0.000000
#
# 0.031295,-0.000018,0.000000,-0.115445,-0.008159,0.000000
#
# -0.021180,-0.001974,0.000000,-0.084437,-0.000073,0.000000
#
# -0.048773,-0.001370,0.000000,-0.024307,0.001394,0.000000
#
# -0.047684,-0.001222,0.000000,0.024543,-0.000433,0.000000
#
# -0.029028,-0.001330,0.000000,0.043704,0.000497,0.000000
#
# -0.008007,-0.000633,0.000000,0.035828,0.002141,0.000000
#
# 0.004759,0.000354,0.000000,0.013984,0.001345,0.000000
#
# 0.006355,0.000609,0.000000,-0.006268,-0.000317,0.000000
#
# 0.000218,0.000149,0.000000,-0.015945,-0.001132,0.000000
#
# -0.007963,-0.000349,0.000000,-0.014826,-0.000828,0.000000
#
# -0.013668,-0.000601,0.000000,-0.007238,-0.000060,0.000000
#
# -0.015163,-0.000533,0.000000,0.001007,0.000234,0.000000
#
# -0.013308,-0.000401,0.000000,0.005653,0.000253,0.000000
#
# -0.010185,-0.000299,0.000000,0.006053,0.000178,0.000000
#
# -0.007702,-0.000244,0.000000,0.003527,0.000008,0.000000
#
# -0.006787,-0.000243,0.000000,0.000226,0.000005,0.000000
#
# -0.007301,-0.000220,0.000000,-0.001950,0.000056,0.000000
#
# -0.008482,-0.000205,0.000000,-0.002445,-0.000020,0.000000
#
# -0.009547,-0.000253,0.000000,-0.001636,-0.000166,0.000000
#
# -0.010040,-0.000382,0.000000,-0.000327,-0.000305,0.000000
#
# -0.009938,-0.000426,0.000000,0.000646,0.000140,0.000000
#
# -0.009489,-0.000305,0.000000,0.001016,0.000237,0.000000
#
# -0.009014,-0.000242,0.000000,0.000793,-0.000024,0.000000
#
# -0.008746,-0.000308,0.000000,0.000268,-0.000185,0.000000
#
# -0.008739,-0.000325,0.000000,-0.000205,0.000092,0.000000
#
# -0.008915,-0.000270,0.000000,-0.000448,-0.000002,0.000000
#
# -0.009141,-0.000325,0.000000,-0.000400,-0.000172,0.000000
#
# -0.009285,-0.000369,0.000000,-0.000154,0.000005,0.000000
#
# -0.009313,-0.000340,0.000000,0.000052,0.000104,0.000000
#
# -0.009237,-0.000288,0.000000,0.000212,0.000104,0.000000
#
# -0.009129,-0.000267,0.000000,0.000186,-0.000057,0.000000
#
# -0.009045,-0.000335,0.000000,0.000136,-0.000146,0.000000
#
# -0.009010,-0.000359,0.000000,0.000014,0.000025,0.000000
#
# -0.009026,-0.000321,0.000000,-0.000076,0.000130,0.000000
#
# -0.009079,-0.000279,0.000000,-0.000124,-0.000054,0.000000
#
# -0.009147,-0.000346,0.000000,-0.000131,-0.000129,0.000000
#
# -0.009195,-0.000362,0.000000,-0.000070,0.000040,0.000000
#
# -0.009213,-0.000320,0.000000,0.000024,0.000105,0.000000
#
# -0.009166,-0.000306,0.000000,0.000156,-0.000118,0.000000
#
# -0.009096,-0.000331,0.000000,0.000120,0.000010,0.000000
#
# -0.009068,-0.000279,0.000000,0.000004,0.000169,0.000000
#
# -0.009088,-0.000221,0.000000,-0.000086,-0.000022,0.000000
#
# -0.009129,-0.000290,0.000000,-0.000052,-0.000232,0.000000
#
# -0.009147,-0.000417,0.000000,-0.000022,-0.000135,0.000000
#
# -0.009151,-0.000353,0.000000,0.000007,0.000184,0.000000
#
# -0.009141,-0.000271,0.000000,0.000030,0.000161,0.000000
#
# -0.009119,-0.000268,0.000000,0.000060,-0.000126,0.000000
#
# -0.009086,-0.000343,0.000000,0.000046,-0.000094,0.000000
#
# -0.009084,-0.000348,0.000000,-0.000040,0.000048,0.000000
#
# -0.009127,-0.000298,0.000000,-0.000117,0.000145,0.000000
#
# -0.009166,-0.000291,0.000000,-0.000050,-0.000108,0.000000
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-d620ac8c7c2f> in <module>()
#      11
#      12 while True:
# ---> 13     f = open(filePath,'r')
#      14     lines = f.readlines()
#      15     if lines[-1] != lastLine:
#
# IOError: [Errno 2] No such file or directory: '/home/fardin/devel/ltzvisor/pc/cmake-build-debug/state.csv'
